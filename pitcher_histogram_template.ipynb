# %%
import pandas as pd
import numpy as np
import pybaseball as pyb
import seaborn as sns

# %%
## Look up player
pyb.playerid_lookup('Gore','Mackenzie')
# Out:
# Gathering player lookup table. This may take a moment.
#   name_last name_first  key_mlbam key_retro key_bbref  key_fangraphs  \
# 0      gore  mackenzie     669022  gorem001  gorema01          22201
#
#    mlb_played_first  mlb_played_last
# 0            2022.0           2024.0

# %%
## Import statcast data

df = pyb.statcast_pitcher(start_dt = '2024-08-28',end_dt = '2024-08-29',player_id = 669022)
df.describe()
# Out:
# Gathering Player Data
#        release_speed  release_pos_x  release_pos_z         batter   pitcher  \
# count     102.000000     102.000000     102.000000     102.000000     102.0
# mean       92.253922       1.851176       5.893725  622538.794118  669022.0
# std         5.385085       0.179853       0.087063   62790.632269       0.0
# min        80.900000       1.460000       5.620000  518934.000000  669022.0
# 25%        87.025000       1.700000       5.842500  592450.000000  669022.0
# 50%        95.700000       1.870000       5.900000  657077.000000  669022.0
# 75%        96.700000       1.997500       5.957500  665862.000000  669022.0
# max        98.500000       2.190000       6.090000  683011.000000  669022.0
#
#        spin_dir  spin_rate_deprecated  break_angle_deprecated  \
# count       0.0                   0.0                     0.0
# mean        NaN                   NaN                     NaN
# std         NaN                   NaN                     NaN
# min         NaN                   NaN                     NaN
# 25%         NaN                   NaN                     NaN
# 50%         NaN                   NaN                     NaN
# 75%         NaN                   NaN                     NaN
# max         NaN                   NaN                     NaN
#
#        break_length_deprecated        zone  ...   fld_score  post_away_score  \
# count                      0.0  102.000000  ...  102.000000       102.000000
# mean                       NaN    8.637255  ...    3.549020         1.068627
# std                        NaN    4.070637  ...    1.686448         0.678668
# min                        NaN    1.000000  ...    0.000000         0.000000
# 25%                        NaN    5.000000  ...    2.000000         1.000000
# 50%                        NaN    9.000000  ...    4.000000         1.000000
# 75%                        NaN   13.000000  ...    5.000000         2.000000
# max                        NaN   14.000000  ...    5.000000         2.000000
#
#        post_home_score  post_bat_score  post_fld_score   spin_axis  \
# count       102.000000      102.000000      102.000000  102.000000
# mean          3.549020        1.068627        3.549020  184.431373
# std           1.686448        0.678668        1.686448   77.206103
# min           0.000000        0.000000        0.000000  116.000000
# 25%           2.000000        1.000000        2.000000  145.000000
# 50%           4.000000        1.000000        4.000000  151.000000
# 75%           5.000000        2.000000        5.000000  159.000000
# max           5.000000        2.000000        5.000000  345.000000
#
#        delta_home_win_exp  delta_run_exp  bat_speed  swing_length
# count          102.000000     102.000000  46.000000     46.000000
# mean             0.001186      -0.014029  71.502277      7.165053
# std              0.021221       0.209181   6.253050      0.963686
# min             -0.096000      -0.613000  49.025470      4.757100
# 25%              0.000000      -0.072500  68.480560      6.608570
# 50%              0.000000      -0.023000  72.279115      7.006995
# 75%              0.000000       0.034750  74.637670      7.658545
# max              0.104000       1.000000  82.691230      9.963080
#
# [8 rows x 77 columns]

# %%
sns.histplot(data = df, x = 'release_speed', hue = 'pitch_name', kde= True)
# Out:
# <Axes: xlabel='release_speed', ylabel='Count'>
